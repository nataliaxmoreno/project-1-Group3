# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd  
from sklearn.datasets import make_blobs
import numpy as np
import csv
from numpy import *
from matplotlib import rc
import pylab
from pylab import *

# %%
data=pd.read_csv('cleanhoney.csv',header=None)
print(data)
# Out:
#        0                   1                 2                 3           4  \
# 0   year  Number of Colonies  Yield Per Colony  Total Production      Stocks
# 1   1998           2621000.0              3008       219519000.0  80565000.0
# 2   1999           2637000.0              2815       202387000.0  78390000.0
# 3   2000           2604000.0              2906       219558000.0  84956000.0
# 4   2001           2542000.0              2840       185748000.0  64764000.0
# 5   2002           2565000.0              2939       171265000.0  39177000.0
# 6   2003           2591000.0              2752       181372000.0  40619000.0
# 7   2004           2539000.0              2657       182729000.0  60981000.0
# 8   2005           2394000.0              2635       173969000.0  62187000.0
# 9   2006           2378000.0              2536       154238000.0  60235000.0
# 10  2007           2428000.0              2426       147621000.0  52405000.0
# ...

# %%
data=df.drop([0,2,4,5,6],axis=1)
print(data)
# Out:
#                      1                 3
# 0   Number of Colonies  Total Production
# 1            2621000.0       219519000.0
# 2            2637000.0       202387000.0
# 3            2604000.0       219558000.0
# 4            2542000.0       185748000.0
# 5            2565000.0       171265000.0
# 6            2591000.0       181372000.0
# 7            2539000.0       182729000.0
# 8            2394000.0       173969000.0
# 9            2378000.0       154238000.0
# 10           2428000.0       147621000.0
# 11           2326000.0       162972000.0
# 12           2472000.0       145068000.0
# 13           2666000.0       175294000.0
# 14           2466000.0       147201000.0
# 15           2509000.0       140907000.0
# 16           2640000.0       149499000.0
# 17           2709000.0       176866000.0
# 18           2630000.0       155376000.0
# 19           2740000.0       160357000.0
# 20           2635000.0       146165000.0
# 21           2767000.0       150949000.0
# ...

# %%
newdata=data.drop([0])
print(newdata)
# Out:
#        0          1     2            3           4                   5  \
# 1   1998  2621000.0  3008  219519000.0  80565000.0                35.8
# 2   1999  2637000.0  2815  202387000.0  78390000.0               34.58
# 3   2000  2604000.0  2906  219558000.0  84956000.0               34.03
# 4   2001  2542000.0  2840  185748000.0  64764000.0               40.12
# 5   2002  2565000.0  2939  171265000.0  39177000.0  60.339999999999996
# 6   2003  2591000.0  2752  181372000.0  40619000.0               65.77
# 7   2004  2539000.0  2657  182729000.0  60981000.0               52.67
# 8   2005  2394000.0  2635  173969000.0  62187000.0                49.0
# 9   2006  2378000.0  2536  154238000.0  60235000.0               53.45
# 10  2007  2428000.0  2426  147621000.0  52405000.0               58.97
# 11  2008  2326000.0  2501  162972000.0  50996000.0               66.65
# 12  2009  2472000.0  2154  145068000.0  37322000.0               72.48
# ...

# %%
fig, ax = plt.subplots(1,1)

plt.scatter(x=newdata[1],y=newdata[3],s=100)
plt.xlabel(1)
plt.ylabel(3)

plt.title("Total Honey Production vs Number of Colonies 1998-2019")

plt.xlabel("Number of Colonies", fontsize=10)
plt.xticks(rotation=90, fontsize=10)

plt.ylabel("Total Honey Production", fontsize=10)

plt.show()
