# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd  
from sklearn.datasets import make_blobs
import numpy as np
import csv
from numpy import *
from matplotlib import pyplot as plt
from matplotlib import rc
import pylab
from decimal import Decimal
from pylab import *

# %%
data=pd.read_csv('cleanhoney.csv',header=None)
print(data)
# Out:
#        0                   1                 2                 3           4  \
# 0   year  Number of Colonies  Yield Per Colony  Total Production      Stocks
# 1   1998           2621000.0              3008       219519000.0  80565000.0
# 2   1999           2637000.0              2815       202387000.0  78390000.0
# 3   2000           2604000.0              2906       219558000.0  84956000.0
# 4   2001           2542000.0              2840       185748000.0  64764000.0
# 5   2002           2565000.0              2939       171265000.0  39177000.0
# 6   2003           2591000.0              2752       181372000.0  40619000.0
# 7   2004           2539000.0              2657       182729000.0  60981000.0
# 8   2005           2394000.0              2635       173969000.0  62187000.0
# 9   2006           2378000.0              2536       154238000.0  60235000.0
# 10  2007           2428000.0              2426       147621000.0  52405000.0
# ...

# %%
data = data.applymap(lambda x: x.replace('.',''))
data
# Out:
#        0                   1                 2                 3          4  \
# 0   year  Number of Colonies  Yield Per Colony  Total Production     Stocks
# 1   1998            26210000              3008        2195190000  805650000
# 2   1999            26370000              2815        2023870000  783900000
# 3   2000            26040000              2906        2195580000  849560000
# 4   2001            25420000              2840        1857480000  647640000
# 5   2002            25650000              2939        1712650000  391770000
# 6   2003            25910000              2752        1813720000  406190000
# 7   2004            25390000              2657        1827290000  609810000
# 8   2005            23940000              2635        1739690000  621870000
# 9   2006            23780000              2536        1542380000  602350000
# 10  2007            24280000              2426        1476210000  524050000
# ...

# %%
data=data.drop([0])
print(data)
# Out:
#        0         1     2           3          4                  5           6
# 1   1998  26210000  3008  2195190000  805650000                358  1460910000
# 2   1999  26370000  2815  2023870000  783900000               3458  1236570000
# 3   2000  26040000  2906  2195580000  849560000               3403  1315680000
# 4   2001  25420000  2840  1857480000  647640000               4012  1322820000
# 5   2002  25650000  2939  1712650000  391770000  60339999999999996  2273020000
# 6   2003  25910000  2752  1813720000  406190000               6577  2520790000
# 7   2004  25390000  2657  1827290000  609810000               5267  1973070000
# 8   2005  23940000  2635  1739690000  621870000                490  1607930000
# 9   2006  23780000  2536  1542380000  602350000               5345  1579240000
# 10  2007  24280000  2426  1476210000  524050000               5897  1613560000
# 11  2008  23260000  2501  1629720000  509960000               6665  2299920000
# ...

# %%
fig, ax = plt.subplots(1,1)

plt.scatter(x=data[1],y=data[3],s=100)
plt.xlabel(1)
plt.ylabel(3)

plt.title("Total Honey Production vs Number of Colonies 1998-2019",fontsize=10)

plt.xlabel("Number of Colonies", fontsize=10)
plt.xticks(rotation=90, fontsize=10)

plt.ylabel("Total Honey Production", fontsize=10)
# Out:
# Text(0, 0.5, 'Total Honey Production')
