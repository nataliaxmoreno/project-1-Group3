# %%
#Load the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import csv
# %matplotlib inline
import matplotlib.ticker as ticker
from matplotlib import ticker

# %%
#Import Bee CSV
bees_data = pd.read_csv("honey bees.csv")

# %%
#Show the data
bees_data
# Out:
#     state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0      AL   16000.0           71   1136000.0    159000.0        0.72
# 1      AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2      AR   53000.0           65   3445000.0   1688000.0        0.59
# 3      CA  450000.0           83  37350000.0  12326000.0        0.62
# 4      CO   27000.0           72   1944000.0   1594000.0        0.70
# ..    ...       ...          ...         ...         ...         ...
# 901    VA    5000.0           39    195000.0     49000.0        7.51
# 902    WA   81000.0           35   2835000.0   1191000.0        2.12
# 903    WV    6000.0           37    222000.0     47000.0        4.50
# 904    WI   46000.0           47   2162000.0    692000.0        2.99
# 905    WY   39000.0           56   2184000.0    306000.0        1.35
#
#       prodvalue  year
# 0      818000.0  1998
# 1     2112000.0  1998
# 2     2033000.0  1998
# 3    23157000.0  1998
# 4     1361000.0  1998
# ..          ...   ...
# 901   1464000.0  2019
# 902   6010000.0  2019
# 903    999000.0  2019
# 904   6464000.0  2019
# 905   2948000.0  2019
#
# [906 rows x 8 columns]

# %%
#Average production of honey per state across the years
bees_state_prod = bees_data[['state', 'totalprod']].groupby('state').mean().round()

# %%
bees_state_prod = pd.DataFrame(bees_state_prod.groupby("state")["totalprod"].mean().round())

# %%
bees_state_prod
# Out:
#         totalprod
# state
# AL       667682.0
# AR      2407182.0
# AZ      1723091.0
# CA     19721136.0
# CO      1614273.0
# FL     14835136.0
# GA      3352045.0
# HI      1043636.0
# IA      2006136.0
# ID      4021000.0
# IL       476227.0
# IN       443500.0
# KS       614318.0
# KY       221045.0
# LA      3777455.0
# MD       211000.0
# ME       298227.0
# MI      4838682.0
# MN      8975682.0
# MO       749000.0
# MS      1521136.0
# MT     11371045.0
# NC      2005909.0
# ND     31714091.0
# NE      2993955.0
# NJ       394182.0
# NM       611688.0
# NV       439273.0
# NY      3604000.0
# OH      1083773.0
# OK       201167.0
# OR      2258773.0
# PA      1792227.0
# SC       582000.0
# SD     17081636.0
# TN       664500.0
# TX      7066818.0
# UT      1059909.0
# VA       358318.0
# VT       349136.0
# WA      2697591.0
# WI      4638818.0
# WV       434682.0
# WY      2498318.0

# %%
bees_state_prod.sort_values('totalprod', ascending=False, inplace=True)
bees_state_prod
# Out:
#         totalprod
# state
# ND     31714091.0
# CA     19721136.0
# SD     17081636.0
# FL     14835136.0
# MT     11371045.0
# MN      8975682.0
# TX      7066818.0
# MI      4838682.0
# WI      4638818.0
# ID      4021000.0
# LA      3777455.0
# NY      3604000.0
# GA      3352045.0
# NE      2993955.0
# WA      2697591.0
# WY      2498318.0
# AR      2407182.0
# OR      2258773.0
# IA      2006136.0
# NC      2005909.0
# PA      1792227.0
# AZ      1723091.0
# CO      1614273.0
# MS      1521136.0
# OH      1083773.0
# UT      1059909.0
# HI      1043636.0
# MO       749000.0
# AL       667682.0
# TN       664500.0
# KS       614318.0
# NM       611688.0
# SC       582000.0
# IL       476227.0
# IN       443500.0
# NV       439273.0
# WV       434682.0
# NJ       394182.0
# VA       358318.0
# VT       349136.0
# ME       298227.0
# KY       221045.0
# MD       211000.0
# OK       201167.0

# %%
#Bar chart for total production per state
x_axis = np.arange(len(bees_state_prod))
tick_locations = bees_data['state'].unique()

plt.bar(x_axis, bees_state_prod['totalprod'],alpha=0.5, edgecolor='chocolate',color="orange")
plt.xticks(x_axis, tick_locations, rotation="vertical")


plt.title("Total Honey Production per State")
plt.xlabel("State")
plt.ylabel("Total Production in Pounds")
plt.figure(figsize=(20,15))
plt.tight_layout()
plt.savefig("honeybystate.png", bbox_inches = "tight", transparent=True)

plt.show()
